# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from math import e
from rsnn.constants import *

# %%
rng = np.random.default_rng(1801)

# %% [markdown]
# # Generate spike train and synaptic connections at random

# %%
from rsnn.rand import *

# %%
n_neurons = 100
period, f_rate = 50.0, 1.0

# %%
# spikes_0 = rand_spikes(n_neurons, 50.0, 1.0, rng)
# spikes_0 = spikes_0.with_columns(pl.lit(0, pl.UInt32).alias("index"))
# spikes_1 = rand_spikes(n_neurons, 40.0, 0.5, rng)
# spikes_1 = spikes_1.with_columns(pl.lit(1, pl.UInt32).alias("index"))
# spikes = pl.concat([spikes_0, spikes_1])
# spikes,

spikes = rand_spikes(n_neurons, period, f_rate, rng)
spikes = spikes.with_columns(pl.lit(0, pl.UInt32).alias("index"))

# %%
n_synapses = 50_000
synapses = rand_synapses(n_neurons, n_synapses, 1.0, 10.0, rng)
# synapses = rand_synapses_fin(n_neurons, n_synapses, 0.1, 10.0, rng)
# synapses = rand_synapses_fout(n_neurons, n_synapses, 0.1, 10.0, rng)
# synapses = rand_synapses_fin_fout(n_neurons, n_synapses, 0.1, 10.0, rng)
# synapses = rand_synapses_fc(n_neurons, 0.1, 10.0, rng)

print(f"in-synapses: {synapses.group_by('target').agg(pl.len()).drop('target').describe(percentiles=None)}")
print(f"out-synapses: {synapses.group_by('source').agg(pl.len()).drop('source').describe(percentiles=None)}")
print(f"synapses: {synapses}")
# Out:
# in-synapses: shape: (6, 2)
# ┌────────────┬───────────┐
# │ statistic  ┆ len       │
# │ ---        ┆ ---       │
# │ str        ┆ f64       │
# ╞════════════╪═══════════╡
# │ count      ┆ 100.0     │
# │ null_count ┆ 0.0       │
# │ mean       ┆ 500.0     │
# │ std        ┆ 22.314103 │
# │ min        ┆ 445.0     │
# │ max        ┆ 551.0     │
# └────────────┴───────────┘
# out-synapses: shape: (6, 2)
# ┌────────────┬───────────┐
# │ statistic  ┆ len       │
# │ ---        ┆ ---       │
# │ str        ┆ f64       │
# ╞════════════╪═══════════╡
# │ count      ┆ 100.0     │
# │ null_count ┆ 0.0       │
# │ mean       ┆ 500.0     │
# │ std        ┆ 23.347615 │
# │ min        ┆ 448.0     │
# │ max        ┆ 556.0     │
# └────────────┴───────────┘
# synapses: shape: (50_000, 5)
# ┌────────┬────────┬──────────┬──────────┬──────────┐
# │ source ┆ target ┆ delay    ┆ weight_0 ┆ weight_1 │
# │ ---    ┆ ---    ┆ ---      ┆ ---      ┆ ---      │
# │ u32    ┆ u32    ┆ f64      ┆ f64      ┆ f64      │
# ╞════════╪════════╪══════════╪══════════╪══════════╡
# │ 86     ┆ 86     ┆ 2.345999 ┆ 0.0      ┆ 0.0      │
# │ 44     ┆ 60     ┆ 8.715286 ┆ 0.0      ┆ 0.0      │
# │ 93     ┆ 88     ┆ 2.939877 ┆ 0.0      ┆ 0.0      │
# │ 34     ┆ 40     ┆ 2.679306 ┆ 0.0      ┆ 0.0      │
# │ 16     ┆ 79     ┆ 3.496688 ┆ 0.0      ┆ 0.0      │
# │ …      ┆ …      ┆ …        ┆ …        ┆ …        │
# │ 56     ┆ 87     ┆ 6.160218 ┆ 0.0      ┆ 0.0      │
# │ 27     ┆ 48     ┆ 5.361969 ┆ 0.0      ┆ 0.0      │
# │ 54     ┆ 53     ┆ 2.239565 ┆ 0.0      ┆ 0.0      │
# │ 43     ┆ 28     ┆ 8.155788 ┆ 0.0      ┆ 0.0      │
# │ 2      ┆ 29     ┆ 7.439887 ┆ 0.0      ┆ 0.0      │
# └────────┴────────┴──────────┴──────────┴──────────┘

# %% [markdown]
# # Optimize synaptic weights

# %%
from rsnn.optim import continuous_offline_optimization

# %%
# spikes, synapses, states = create_offline_states(spikes, synapses)

# %%
synapses_opt = continuous_offline_optimization(spikes, synapses, wmin=-0.3, wmax=0.3, dzmin=1.0, l2_obj_scale=0.0)
# Out:
# 2025-08-28 15:42:18.583' - INFO - Neuron 86. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:18.677' - INFO - Neuron 60. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:18.745' - INFO - Neuron 88. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:18.805' - INFO - Neuron 40. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:18.893' - INFO - Neuron 79. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:18.962' - INFO - Neuron 84. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:19.192' - INFO - Neuron 95. Optimization successful (in 11 iterations)
# 2025-08-28 15:42:19.258' - INFO - Neuron 61. Optimization successful (in 4 iterations)
# 2025-08-28 15:42:19.372' - INFO - Neuron 15. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:19.479' - INFO - Neuron 58. Optimization successful (in 10 iterations)
# 2025-08-28 15:42:19.571' - INFO - Neuron 29. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:19.633' - INFO - Neuron 82. Optimization successful (in 4 iterations)
# 2025-08-28 15:42:19.693' - INFO - Neuron 55. Optimization successful (in 4 iterations)
# 2025-08-28 15:42:19.808' - INFO - Neuron 42. Optimization successful (in 11 iterations)
# 2025-08-28 15:42:19.943' - INFO - Neuron 24. Optimization successful (in 13 iterations)
# 2025-08-28 15:42:19.993' - INFO - Neuron 91. Optimization successful (in 4 iterations)
# 2025-08-28 15:42:20.058' - INFO - Neuron 14. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:20.161' - INFO - Neuron 3. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:20.255' - INFO - Neuron 32. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:20.358' - INFO - Neuron 11. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:20.451' - INFO - Neuron 37. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:20.524' - INFO - Neuron 76. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:20.638' - INFO - Neuron 72. Optimization successful (in 11 iterations)
# 2025-08-28 15:42:20.715' - INFO - Neuron 43. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:20.803' - INFO - Neuron 10. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:20.878' - INFO - Neuron 99. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:20.963' - INFO - Neuron 19. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:21.017' - INFO - Neuron 75. Optimization successful (in 4 iterations)
# 2025-08-28 15:42:21.131' - INFO - Neuron 94. Optimization successful (in 10 iterations)
# 2025-08-28 15:42:21.220' - INFO - Neuron 1. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:21.351' - INFO - Neuron 63. Optimization successful (in 13 iterations)
# 2025-08-28 15:42:21.419' - INFO - Neuron 89. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:21.483' - INFO - Neuron 56. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:21.581' - INFO - Neuron 5. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:21.658' - INFO - Neuron 96. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:21.738' - INFO - Neuron 59. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:21.827' - INFO - Neuron 16. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:21.903' - INFO - Neuron 38. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:21.979' - INFO - Neuron 17. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:22.047' - INFO - Neuron 18. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:22.131' - INFO - Neuron 28. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:22.196' - INFO - Neuron 34. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:22.332' - INFO - Neuron 93. Optimization successful (in 15 iterations)
# 2025-08-28 15:42:22.373' - INFO - Neuron 31. Optimization successful (in 3 iterations)
# 2025-08-28 15:42:22.438' - INFO - Neuron 53. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:22.513' - INFO - Neuron 6. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:22.564' - INFO - Neuron 80. Optimization successful (in 4 iterations)
# 2025-08-28 15:42:22.657' - INFO - Neuron 64. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:22.719' - INFO - Neuron 45. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:22.838' - INFO - Neuron 4. Optimization successful (in 12 iterations)
# 2025-08-28 15:42:22.917' - INFO - Neuron 26. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:23.045' - INFO - Neuron 65. Optimization successful (in 13 iterations)
# 2025-08-28 15:42:23.119' - INFO - Neuron 7. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:23.207' - INFO - Neuron 39. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:23.296' - INFO - Neuron 44. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:23.354' - INFO - Neuron 69. Optimization successful (in 4 iterations)
# 2025-08-28 15:42:23.444' - INFO - Neuron 87. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:23.513' - INFO - Neuron 21. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:23.603' - INFO - Neuron 49. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:23.710' - INFO - Neuron 50. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:23.869' - INFO - Neuron 48. Optimization successful (in 17 iterations)
# 2025-08-28 15:42:23.980' - INFO - Neuron 62. Optimization successful (in 11 iterations)
# 2025-08-28 15:42:24.053' - INFO - Neuron 27. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:24.146' - INFO - Neuron 57. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:24.214' - INFO - Neuron 33. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:24.309' - INFO - Neuron 41. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:24.410' - INFO - Neuron 47. Optimization successful (in 10 iterations)
# 2025-08-28 15:42:24.472' - INFO - Neuron 77. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:24.557' - INFO - Neuron 51. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:24.657' - INFO - Neuron 98. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:24.784' - INFO - Neuron 81. Optimization successful (in 13 iterations)
# 2025-08-28 15:42:24.864' - INFO - Neuron 74. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:25.060' - INFO - Neuron 46. Optimization successful (in 21 iterations)
# 2025-08-28 15:42:25.158' - INFO - Neuron 36. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:25.222' - INFO - Neuron 67. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:25.308' - INFO - Neuron 22. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:25.387' - INFO - Neuron 71. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:25.474' - INFO - Neuron 66. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:25.536' - INFO - Neuron 9. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:25.589' - INFO - Neuron 73. Optimization successful (in 4 iterations)
# 2025-08-28 15:42:25.671' - INFO - Neuron 52. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:25.773' - INFO - Neuron 23. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:25.840' - INFO - Neuron 12. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:25.913' - INFO - Neuron 54. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:26.028' - INFO - Neuron 30. Optimization successful (in 11 iterations)
# 2025-08-28 15:42:26.121' - INFO - Neuron 0. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:26.182' - INFO - Neuron 20. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:26.258' - INFO - Neuron 70. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:26.363' - INFO - Neuron 97. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:26.484' - INFO - Neuron 13. Optimization successful (in 12 iterations)
# 2025-08-28 15:42:26.582' - INFO - Neuron 92. Optimization successful (in 9 iterations)
# 2025-08-28 15:42:26.656' - INFO - Neuron 8. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:26.710' - INFO - Neuron 90. Optimization successful (in 4 iterations)
# 2025-08-28 15:42:26.811' - INFO - Neuron 2. Optimization successful (in 10 iterations)
# 2025-08-28 15:42:26.882' - INFO - Neuron 68. Optimization successful (in 5 iterations)
# 2025-08-28 15:42:26.967' - INFO - Neuron 78. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:27.066' - INFO - Neuron 83. Optimization successful (in 8 iterations)
# 2025-08-28 15:42:27.145' - INFO - Neuron 85. Optimization successful (in 6 iterations)
# 2025-08-28 15:42:27.243' - INFO - Neuron 25. Optimization successful (in 7 iterations)
# 2025-08-28 15:42:27.361' - INFO - Neuron 35. Optimization successful (in 9 iterations)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
res = ax.hist(synapses_opt["weight_1"].to_numpy(), bins=25)
# res = ax.set_xlabel("weight")
# res = ax.set_ylabel("count")

# %% [markdown]
# # Evaluate asymptotic stability

# %%
from rsnn.jitters import *

# %%
Phi = compute_phi_matrix(spikes.filter(pl.col("index")==0), synapses_opt)

# %%
top_phis = compute_non_global_phi_eigenvals(Phi, k=1)
np.abs(top_phis)
# Out:
# array([0.0001575])

# %%
top_phis = compute_non_global_phi_eigenvals(Phi, k=250)
plt.plot(top_phis.real, top_phis.imag, "o")
plt.xlabel("Re")
plt.ylabel("Im")
# Out:
# Text(0, 0.5, 'Im')

# %% [markdown]
# # Simulate network

# %%
from rsnn.sim import simulate, create_initial_states
from rsnn.channels import compute_min_delays

# %%
# Fastest communications due to synaptic connections
min_delays = compute_min_delays(n_neurons, synapses_opt)

# %%
std_jitter = 1e-9  # the lower the spectral radius, the largest this quantity can be
spikes_ref = spikes.filter(pl.col("index") == 0).select("neuron", "time", "period").sort("time")
initial_drift = rng.normal(0.0, std_jitter, spikes_ref.height)
spikes_sim = spikes_ref.select(
    pl.col("neuron"),
    pl.col("time") - period + initial_drift,
)

# Initial neuron states (last firing times and firing thresholds)
# f_thresh_noise = lambda n: FIRING_THRESHOLD
f_thresh_noise = lambda n: rng.normal(FIRING_THRESHOLD, 1e-9, n)
neurons = pl.DataFrame(
    {
        "neuron": np.arange(n_neurons, dtype=np.uint32),
        "f_thresh": f_thresh_noise(n_neurons),
    }
)
neurons = neurons.with_columns(pl.lit(None, pl.Float64).alias("last_f_time"))
neurons = neurons.update(
    spikes_sim.group_by("neuron").agg(pl.max("time").alias("last_f_time")), on="neuron"
)

# %%
# Initial states
states_sim = create_initial_states(neurons, spikes_sim, synapses_opt)

# %%
spikes_sim, states_sim = simulate(
    neurons,
    spikes_sim,
    synapses_opt,
    min_delays,
    states_sim,
    period,
    10 * period,
    f_thresh_noise=f_thresh_noise,
)
# Out:
# 2025-08-28 15:38:37.703' - DEBUG - Simulation time: 0.018862600041212055
# 2025-08-28 15:38:37.730' - DEBUG - Simulation time: 1.2228194852583891
# 2025-08-28 15:38:37.749' - DEBUG - Simulation time: 2.245122819396869
# 2025-08-28 15:38:37.762' - DEBUG - Simulation time: 3.441391550232643
# 2025-08-28 15:38:37.774' - DEBUG - Simulation time: 4.6135824246627966
# 2025-08-28 15:38:37.786' - DEBUG - Simulation time: 5.904824960060564
# 2025-08-28 15:38:37.798' - DEBUG - Simulation time: 6.985023257185955
# 2025-08-28 15:38:37.811' - DEBUG - Simulation time: 8.301299803701603
# 2025-08-28 15:38:37.824' - DEBUG - Simulation time: 9.53457289897308
# 2025-08-28 15:38:37.836' - DEBUG - Simulation time: 10.701343713274536
# 2025-08-28 15:38:37.848' - DEBUG - Simulation time: 11.798774361373699
# 2025-08-28 15:38:37.860' - DEBUG - Simulation time: 12.954733030602432
# 2025-08-28 15:38:37.873' - DEBUG - Simulation time: 14.230365538371743
# 2025-08-28 15:38:37.886' - DEBUG - Simulation time: 15.336427379247379
# 2025-08-28 15:38:37.899' - DEBUG - Simulation time: 16.51229462217287
# 2025-08-28 15:38:37.912' - DEBUG - Simulation time: 17.82252955591239
# 2025-08-28 15:38:37.926' - DEBUG - Simulation time: 18.993471638584804
# 2025-08-28 15:38:37.939' - DEBUG - Simulation time: 20.235517399333638
# 2025-08-28 15:38:37.952' - DEBUG - Simulation time: 21.519713683707348
# 2025-08-28 15:38:37.964' - DEBUG - Simulation time: 22.690215258955085
# 2025-08-28 15:38:37.977' - DEBUG - Simulation time: 23.80075600446515
# 2025-08-28 15:38:37.989' - DEBUG - Simulation time: 25.011123827596442
# 2025-08-28 15:38:38.001' - DEBUG - Simulation time: 26.20546723306561
# 2025-08-28 15:38:38.012' - DEBUG - Simulation time: 27.39401859093599
# 2025-08-28 15:38:38.025' - DEBUG - Simulation time: 28.775560330403245
# 2025-08-28 15:38:38.037' - DEBUG - Simulation time: 29.89605575265087
# 2025-08-28 15:38:38.050' - DEBUG - Simulation time: 31.214074123682146
# 2025-08-28 15:38:38.062' - DEBUG - Simulation time: 32.313836423671134
# 2025-08-28 15:38:38.075' - DEBUG - Simulation time: 33.5352575611137
# 2025-08-28 15:38:38.088' - DEBUG - Simulation time: 34.63554342451561
# 2025-08-28 15:38:38.101' - DEBUG - Simulation time: 35.77921516602546
# 2025-08-28 15:38:38.113' - DEBUG - Simulation time: 37.124551547178655
# 2025-08-28 15:38:38.126' - DEBUG - Simulation time: 38.27964404735267
# 2025-08-28 15:38:38.138' - DEBUG - Simulation time: 39.46124272733415
# 2025-08-28 15:38:38.151' - DEBUG - Simulation time: 40.600884717169116
# 2025-08-28 15:38:38.163' - DEBUG - Simulation time: 41.7202701438515
# 2025-08-28 15:38:38.175' - DEBUG - Simulation time: 42.90127133400138
# 2025-08-28 15:38:38.188' - DEBUG - Simulation time: 44.268347606355526
# 2025-08-28 15:38:38.201' - DEBUG - Simulation time: 45.56815763612553
# 2025-08-28 15:38:38.213' - DEBUG - Simulation time: 46.66030308568062
# 2025-08-28 15:38:38.225' - DEBUG - Simulation time: 47.814088912508886
# 2025-08-28 15:38:38.238' - DEBUG - Simulation time: 49.04602594329408
# 2025-08-28 15:38:38.250' - DEBUG - Simulation time: 50.34587542032942
# 2025-08-28 15:38:38.262' - DEBUG - Simulation time: 51.38561621247691
# 2025-08-28 15:38:38.275' - DEBUG - Simulation time: 52.460003067758294
# 2025-08-28 15:38:38.287' - DEBUG - Simulation time: 53.65329519960614
# 2025-08-28 15:38:38.300' - DEBUG - Simulation time: 54.88805454069333
# 2025-08-28 15:38:38.311' - DEBUG - Simulation time: 55.904824959891556
# 2025-08-28 15:38:38.324' - DEBUG - Simulation time: 57.21952910089846
# 2025-08-28 15:38:38.336' - DEBUG - Simulation time: 58.406276675792675
# 2025-08-28 15:38:38.347' - DEBUG - Simulation time: 59.53457289946222
# 2025-08-28 15:38:38.360' - DEBUG - Simulation time: 60.7013437132477
# 2025-08-28 15:38:38.373' - DEBUG - Simulation time: 61.79877436119489
# 2025-08-28 15:38:38.384' - DEBUG - Simulation time: 62.95473303081065
# 2025-08-28 15:38:38.397' - DEBUG - Simulation time: 64.23036553837521
# 2025-08-28 15:38:38.409' - DEBUG - Simulation time: 65.33642737935622
# 2025-08-28 15:38:38.421' - DEBUG - Simulation time: 66.51229462220812
# 2025-08-28 15:38:38.435' - DEBUG - Simulation time: 67.82252955610295
# 2025-08-28 15:38:38.447' - DEBUG - Simulation time: 68.99347163847936
# 2025-08-28 15:38:38.460' - DEBUG - Simulation time: 70.23551739902294
# 2025-08-28 15:38:38.473' - DEBUG - Simulation time: 71.51971368352217
# 2025-08-28 15:38:38.486' - DEBUG - Simulation time: 72.69021525856625
# 2025-08-28 15:38:38.497' - DEBUG - Simulation time: 73.80075600447239
# 2025-08-28 15:38:38.510' - DEBUG - Simulation time: 75.01112382768544
# 2025-08-28 15:38:38.522' - DEBUG - Simulation time: 76.20546723364572
# 2025-08-28 15:38:38.533' - DEBUG - Simulation time: 77.39401859100205
# 2025-08-28 15:38:38.545' - DEBUG - Simulation time: 78.77556033032985
# 2025-08-28 15:38:38.557' - DEBUG - Simulation time: 79.89605575278961
# 2025-08-28 15:38:38.569' - DEBUG - Simulation time: 81.21407412368225
# 2025-08-28 15:38:38.582' - DEBUG - Simulation time: 82.31383642388019
# 2025-08-28 15:38:38.594' - DEBUG - Simulation time: 83.53525756101436
# 2025-08-28 15:38:38.607' - DEBUG - Simulation time: 84.63554342433572
# 2025-08-28 15:38:38.619' - DEBUG - Simulation time: 85.7792151660423
# 2025-08-28 15:38:38.632' - DEBUG - Simulation time: 87.12455154722429
# 2025-08-28 15:38:38.644' - DEBUG - Simulation time: 88.27964404778137
# 2025-08-28 15:38:38.657' - DEBUG - Simulation time: 89.46124272724761
# 2025-08-28 15:38:38.669' - DEBUG - Simulation time: 90.60088471700254
# 2025-08-28 15:38:38.681' - DEBUG - Simulation time: 91.72027014390554
# 2025-08-28 15:38:38.709' - DEBUG - Simulation time: 92.90127133380346
# 2025-08-28 15:38:38.721' - DEBUG - Simulation time: 94.26834760630346
# 2025-08-28 15:38:38.733' - DEBUG - Simulation time: 95.56815763593056
# 2025-08-28 15:38:38.744' - DEBUG - Simulation time: 96.66030308565641
# 2025-08-28 15:38:38.757' - DEBUG - Simulation time: 97.81408891237587
# 2025-08-28 15:38:38.770' - DEBUG - Simulation time: 99.04602594324395
# 2025-08-28 15:38:38.783' - DEBUG - Simulation time: 100.34587542075198
# 2025-08-28 15:38:38.795' - DEBUG - Simulation time: 101.38561621264905
# 2025-08-28 15:38:38.807' - DEBUG - Simulation time: 102.4600030675798
# 2025-08-28 15:38:38.820' - DEBUG - Simulation time: 103.65329519941122
# 2025-08-28 15:38:38.833' - DEBUG - Simulation time: 104.88805454039465
# 2025-08-28 15:38:38.844' - DEBUG - Simulation time: 105.90482495991469
# 2025-08-28 15:38:38.857' - DEBUG - Simulation time: 107.21952910136996
# 2025-08-28 15:38:38.869' - DEBUG - Simulation time: 108.40627667571707
# 2025-08-28 15:38:38.881' - DEBUG - Simulation time: 109.53457289947366
# 2025-08-28 15:38:38.893' - DEBUG - Simulation time: 110.70134371287847
# 2025-08-28 15:38:38.906' - DEBUG - Simulation time: 111.79877436134694
# 2025-08-28 15:38:38.918' - DEBUG - Simulation time: 112.95473303065296
# 2025-08-28 15:38:38.930' - DEBUG - Simulation time: 114.23036553840792
# 2025-08-28 15:38:38.942' - DEBUG - Simulation time: 115.33642737917582
# 2025-08-28 15:38:38.955' - DEBUG - Simulation time: 116.512294622204
# 2025-08-28 15:38:38.969' - DEBUG - Simulation time: 117.82252955629797
# 2025-08-28 15:38:38.981' - DEBUG - Simulation time: 118.99347163862619
# 2025-08-28 15:38:38.994' - DEBUG - Simulation time: 120.23551739939235
# 2025-08-28 15:38:39.006' - DEBUG - Simulation time: 121.5197136836761
# 2025-08-28 15:38:39.018' - DEBUG - Simulation time: 122.69021525860279
# 2025-08-28 15:38:39.030' - DEBUG - Simulation time: 123.80075600432312
# 2025-08-28 15:38:39.041' - DEBUG - Simulation time: 125.01112382773117
# 2025-08-28 15:38:39.053' - DEBUG - Simulation time: 126.20546723332357
# 2025-08-28 15:38:39.064' - DEBUG - Simulation time: 127.39401859107836
# 2025-08-28 15:38:39.077' - DEBUG - Simulation time: 128.77556033015452
# 2025-08-28 15:38:39.089' - DEBUG - Simulation time: 129.8960557525667
# 2025-08-28 15:38:39.101' - DEBUG - Simulation time: 131.2140741236181
# 2025-08-28 15:38:39.113' - DEBUG - Simulation time: 132.3138364237232
# 2025-08-28 15:38:39.126' - DEBUG - Simulation time: 133.5352575608638
# 2025-08-28 15:38:39.139' - DEBUG - Simulation time: 134.63554342410464
# 2025-08-28 15:38:39.152' - DEBUG - Simulation time: 135.77921516603536
# 2025-08-28 15:38:39.165' - DEBUG - Simulation time: 137.12455154708948
# 2025-08-28 15:38:39.177' - DEBUG - Simulation time: 138.27964404758117
# 2025-08-28 15:38:39.190' - DEBUG - Simulation time: 139.46124272750836
# 2025-08-28 15:38:39.202' - DEBUG - Simulation time: 140.60088471696525
# 2025-08-28 15:38:39.213' - DEBUG - Simulation time: 141.7202701440193
# 2025-08-28 15:38:39.225' - DEBUG - Simulation time: 142.90127133373537
# 2025-08-28 15:38:39.237' - DEBUG - Simulation time: 144.26834760615654
# 2025-08-28 15:38:39.250' - DEBUG - Simulation time: 145.56815763599434
# 2025-08-28 15:38:39.261' - DEBUG - Simulation time: 146.6603030856933
# 2025-08-28 15:38:39.274' - DEBUG - Simulation time: 147.81408891235463
# 2025-08-28 15:38:39.286' - DEBUG - Simulation time: 149.04602594328344
# 2025-08-28 15:38:39.300' - DEBUG - Simulation time: 150.34587542018787
# 2025-08-28 15:38:39.311' - DEBUG - Simulation time: 151.38561621273922
# 2025-08-28 15:38:39.324' - DEBUG - Simulation time: 152.46000306755545
# 2025-08-28 15:38:39.335' - DEBUG - Simulation time: 153.65329519960397
# 2025-08-28 15:38:39.348' - DEBUG - Simulation time: 154.8880545405217
# 2025-08-28 15:38:39.360' - DEBUG - Simulation time: 155.90482496006175
# 2025-08-28 15:38:39.373' - DEBUG - Simulation time: 157.21952910136
# 2025-08-28 15:38:39.385' - DEBUG - Simulation time: 158.4062766758242
# 2025-08-28 15:38:39.397' - DEBUG - Simulation time: 159.53457289932604
# 2025-08-28 15:38:39.410' - DEBUG - Simulation time: 160.7013437137867
# 2025-08-28 15:38:39.421' - DEBUG - Simulation time: 161.7987743612975
# 2025-08-28 15:38:39.434' - DEBUG - Simulation time: 162.95473303065694
# 2025-08-28 15:38:39.446' - DEBUG - Simulation time: 164.23036553837383
# 2025-08-28 15:38:39.526' - DEBUG - Simulation time: 165.33642737929122
# 2025-08-28 15:38:39.557' - DEBUG - Simulation time: 166.51229462200112
# 2025-08-28 15:38:39.569' - DEBUG - Simulation time: 167.82252955605938
# 2025-08-28 15:38:39.581' - DEBUG - Simulation time: 168.99347163859383
# 2025-08-28 15:38:39.594' - DEBUG - Simulation time: 170.23551739933447
# 2025-08-28 15:38:39.607' - DEBUG - Simulation time: 171.51971368378722
# 2025-08-28 15:38:39.619' - DEBUG - Simulation time: 172.6902152586989
# 2025-08-28 15:38:39.630' - DEBUG - Simulation time: 173.80075600438724
# 2025-08-28 15:38:39.643' - DEBUG - Simulation time: 175.01112382756838
# 2025-08-28 15:38:39.655' - DEBUG - Simulation time: 176.20546723342932
# 2025-08-28 15:38:39.667' - DEBUG - Simulation time: 177.39401859116106
# 2025-08-28 15:38:39.679' - DEBUG - Simulation time: 178.77556033034278
# 2025-08-28 15:38:39.692' - DEBUG - Simulation time: 179.89605575249695
# 2025-08-28 15:38:39.705' - DEBUG - Simulation time: 181.2140741236325
# 2025-08-28 15:38:39.718' - DEBUG - Simulation time: 182.31383642374553
# 2025-08-28 15:38:39.729' - DEBUG - Simulation time: 183.53525756116235
# 2025-08-28 15:38:39.742' - DEBUG - Simulation time: 184.6355434240628
# 2025-08-28 15:38:39.753' - DEBUG - Simulation time: 185.77921516585025
# 2025-08-28 15:38:39.766' - DEBUG - Simulation time: 187.12455154706956
# 2025-08-28 15:38:39.778' - DEBUG - Simulation time: 188.27964404721544
# 2025-08-28 15:38:39.791' - DEBUG - Simulation time: 189.46124272699234
# 2025-08-28 15:38:39.803' - DEBUG - Simulation time: 190.60088471701295
# 2025-08-28 15:38:39.815' - DEBUG - Simulation time: 191.72027014392097
# 2025-08-28 15:38:39.827' - DEBUG - Simulation time: 192.90127133368733
# 2025-08-28 15:38:39.839' - DEBUG - Simulation time: 194.26834760606764
# 2025-08-28 15:38:39.851' - DEBUG - Simulation time: 195.56815763613918
# 2025-08-28 15:38:39.863' - DEBUG - Simulation time: 196.66030308564714
# 2025-08-28 15:38:39.875' - DEBUG - Simulation time: 197.81408891217697
# 2025-08-28 15:38:39.887' - DEBUG - Simulation time: 199.0460259430712
# 2025-08-28 15:38:39.900' - DEBUG - Simulation time: 200.34587542018085
# 2025-08-28 15:38:39.912' - DEBUG - Simulation time: 201.38561621229843
# 2025-08-28 15:38:39.924' - DEBUG - Simulation time: 202.4600030675673
# 2025-08-28 15:38:39.937' - DEBUG - Simulation time: 203.6532951994744
# 2025-08-28 15:38:39.950' - DEBUG - Simulation time: 204.88805454037416
# 2025-08-28 15:38:39.961' - DEBUG - Simulation time: 205.90482495996073
# 2025-08-28 15:38:39.974' - DEBUG - Simulation time: 207.21952910135988
# 2025-08-28 15:38:39.987' - DEBUG - Simulation time: 208.40627667583925
# 2025-08-28 15:38:39.999' - DEBUG - Simulation time: 209.53457289935412
# 2025-08-28 15:38:40.011' - DEBUG - Simulation time: 210.7013437132588
# 2025-08-28 15:38:40.024' - DEBUG - Simulation time: 211.79877436115441
# 2025-08-28 15:38:40.036' - DEBUG - Simulation time: 212.95473303058213
# 2025-08-28 15:38:40.049' - DEBUG - Simulation time: 214.23036553836317
# 2025-08-28 15:38:40.060' - DEBUG - Simulation time: 215.3364273791881
# 2025-08-28 15:38:40.073' - DEBUG - Simulation time: 216.51229462220448
# 2025-08-28 15:38:40.086' - DEBUG - Simulation time: 217.82252955604207
# 2025-08-28 15:38:40.098' - DEBUG - Simulation time: 218.9934716386042
# 2025-08-28 15:38:40.111' - DEBUG - Simulation time: 220.23551739923883
# 2025-08-28 15:38:40.124' - DEBUG - Simulation time: 221.519713683788
# 2025-08-28 15:38:40.136' - DEBUG - Simulation time: 222.6902152585572
# 2025-08-28 15:38:40.148' - DEBUG - Simulation time: 223.8007560043596
# 2025-08-28 15:38:40.160' - DEBUG - Simulation time: 225.01112382769517
# 2025-08-28 15:38:40.173' - DEBUG - Simulation time: 226.2054672334942
# 2025-08-28 15:38:40.185' - DEBUG - Simulation time: 227.39401859080266
# 2025-08-28 15:38:40.196' - DEBUG - Simulation time: 228.7755603302854
# 2025-08-28 15:38:40.209' - DEBUG - Simulation time: 229.8960557526821
# 2025-08-28 15:38:40.222' - DEBUG - Simulation time: 231.2140741236046
# 2025-08-28 15:38:40.235' - DEBUG - Simulation time: 232.3138364237256
# 2025-08-28 15:38:40.247' - DEBUG - Simulation time: 233.53525756082993
# 2025-08-28 15:38:40.260' - DEBUG - Simulation time: 234.63554342423325
# 2025-08-28 15:38:40.273' - DEBUG - Simulation time: 235.7792151657899
# 2025-08-28 15:38:40.286' - DEBUG - Simulation time: 237.12455154719916
# 2025-08-28 15:38:40.297' - DEBUG - Simulation time: 238.27964404731915
# 2025-08-28 15:38:40.310' - DEBUG - Simulation time: 239.46124272723628
# 2025-08-28 15:38:40.322' - DEBUG - Simulation time: 240.60088471702338
# 2025-08-28 15:38:40.334' - DEBUG - Simulation time: 241.720270144034
# 2025-08-28 15:38:40.345' - DEBUG - Simulation time: 242.90127133355475
# 2025-08-28 15:38:40.357' - DEBUG - Simulation time: 244.2683476061872
# 2025-08-28 15:38:40.370' - DEBUG - Simulation time: 245.5681576359562
# 2025-08-28 15:38:40.382' - DEBUG - Simulation time: 246.66030308585368
# 2025-08-28 15:38:40.394' - DEBUG - Simulation time: 247.81408891222353
# 2025-08-28 15:38:40.407' - DEBUG - Simulation time: 249.04602594297333
# 2025-08-28 15:38:40.419' - DEBUG - Simulation time: 250.3458754202232
# 2025-08-28 15:38:40.431' - DEBUG - Simulation time: 251.38561621241044
# 2025-08-28 15:38:40.443' - DEBUG - Simulation time: 252.46000306761897
# 2025-08-28 15:38:40.456' - DEBUG - Simulation time: 253.65329519940968
# 2025-08-28 15:38:40.468' - DEBUG - Simulation time: 254.8880545404976
# 2025-08-28 15:38:40.480' - DEBUG - Simulation time: 255.90482495973228
# 2025-08-28 15:38:40.506' - DEBUG - Simulation time: 257.21952910118574
# 2025-08-28 15:38:40.518' - DEBUG - Simulation time: 258.40627667573926
# 2025-08-28 15:38:40.530' - DEBUG - Simulation time: 259.53457289904287
# 2025-08-28 15:38:40.542' - DEBUG - Simulation time: 260.70134371329164
# 2025-08-28 15:38:40.554' - DEBUG - Simulation time: 261.7987743613023
# 2025-08-28 15:38:40.566' - DEBUG - Simulation time: 262.9547330306865
# 2025-08-28 15:38:40.578' - DEBUG - Simulation time: 264.2303655383082
# 2025-08-28 15:38:40.590' - DEBUG - Simulation time: 265.3364273792722
# 2025-08-28 15:38:40.603' - DEBUG - Simulation time: 266.51229462201417
# 2025-08-28 15:38:40.614' - DEBUG - Simulation time: 267.82252955591366
# 2025-08-28 15:38:40.627' - DEBUG - Simulation time: 268.9934716385645
# 2025-08-28 15:38:40.640' - DEBUG - Simulation time: 270.23551739928337
# 2025-08-28 15:38:40.652' - DEBUG - Simulation time: 271.51971368366446
# 2025-08-28 15:38:40.664' - DEBUG - Simulation time: 272.6902152587193
# 2025-08-28 15:38:40.677' - DEBUG - Simulation time: 273.80075600430985
# 2025-08-28 15:38:40.688' - DEBUG - Simulation time: 275.0111238274894
# 2025-08-28 15:38:40.701' - DEBUG - Simulation time: 276.2054672329494
# 2025-08-28 15:38:40.712' - DEBUG - Simulation time: 277.39401859105794
# 2025-08-28 15:38:40.725' - DEBUG - Simulation time: 278.7755603302061
# 2025-08-28 15:38:40.736' - DEBUG - Simulation time: 279.896055752595
# 2025-08-28 15:38:40.749' - DEBUG - Simulation time: 281.21407412373765
# 2025-08-28 15:38:40.762' - DEBUG - Simulation time: 282.31383642369406
# 2025-08-28 15:38:40.775' - DEBUG - Simulation time: 283.5352575611864
# 2025-08-28 15:38:40.788' - DEBUG - Simulation time: 284.63554342432786
# 2025-08-28 15:38:40.801' - DEBUG - Simulation time: 285.7792151659453
# 2025-08-28 15:38:40.813' - DEBUG - Simulation time: 287.1245515471679
# 2025-08-28 15:38:40.826' - DEBUG - Simulation time: 288.2796440473274
# 2025-08-28 15:38:40.838' - DEBUG - Simulation time: 289.46124272731845
# 2025-08-28 15:38:40.851' - DEBUG - Simulation time: 290.6008847171453
# 2025-08-28 15:38:40.862' - DEBUG - Simulation time: 291.72027014388163
# 2025-08-28 15:38:40.874' - DEBUG - Simulation time: 292.9012713336996
# 2025-08-28 15:38:40.887' - DEBUG - Simulation time: 294.2683476062607
# 2025-08-28 15:38:40.898' - DEBUG - Simulation time: 295.5681576359691
# 2025-08-28 15:38:40.910' - DEBUG - Simulation time: 296.6603030855274
# 2025-08-28 15:38:40.922' - DEBUG - Simulation time: 297.8140889120472
# 2025-08-28 15:38:40.935' - DEBUG - Simulation time: 299.0460259430082
# 2025-08-28 15:38:40.946' - DEBUG - Simulation time: 300.34587542041396
# 2025-08-28 15:38:40.958' - DEBUG - Simulation time: 301.38561621247413
# 2025-08-28 15:38:40.971' - DEBUG - Simulation time: 302.4600030675563
# 2025-08-28 15:38:40.983' - DEBUG - Simulation time: 303.65329519920556
# 2025-08-28 15:38:40.995' - DEBUG - Simulation time: 304.88805454045695
# 2025-08-28 15:38:41.008' - DEBUG - Simulation time: 305.90482496001846
# 2025-08-28 15:38:41.020' - DEBUG - Simulation time: 307.2195291013866
# 2025-08-28 15:38:41.033' - DEBUG - Simulation time: 308.40627667582095
# 2025-08-28 15:38:41.045' - DEBUG - Simulation time: 309.534572899377
# 2025-08-28 15:38:41.057' - DEBUG - Simulation time: 310.70134371336474
# 2025-08-28 15:38:41.068' - DEBUG - Simulation time: 311.7987743613071
# 2025-08-28 15:38:41.081' - DEBUG - Simulation time: 312.95473303062954
# 2025-08-28 15:38:41.094' - DEBUG - Simulation time: 314.2303655385979
# 2025-08-28 15:38:41.106' - DEBUG - Simulation time: 315.3364273792798
# 2025-08-28 15:38:41.118' - DEBUG - Simulation time: 316.5122946221513
# 2025-08-28 15:38:41.131' - DEBUG - Simulation time: 317.8225295561768
# 2025-08-28 15:38:41.144' - DEBUG - Simulation time: 318.9934716383305
# 2025-08-28 15:38:41.157' - DEBUG - Simulation time: 320.2355173991596
# 2025-08-28 15:38:41.170' - DEBUG - Simulation time: 321.51971368348114
# 2025-08-28 15:38:41.183' - DEBUG - Simulation time: 322.6902152585059
# 2025-08-28 15:38:41.194' - DEBUG - Simulation time: 323.8007560044644
# 2025-08-28 15:38:41.207' - DEBUG - Simulation time: 325.01112382771043
# 2025-08-28 15:38:41.218' - DEBUG - Simulation time: 326.2054672332746
# 2025-08-28 15:38:41.230' - DEBUG - Simulation time: 327.3940185910602
# 2025-08-28 15:38:41.242' - DEBUG - Simulation time: 328.775560330183
# 2025-08-28 15:38:41.255' - DEBUG - Simulation time: 329.8960557525941
# 2025-08-28 15:38:41.267' - DEBUG - Simulation time: 331.21407412344183
# 2025-08-28 15:38:41.279' - DEBUG - Simulation time: 332.3138364235568
# 2025-08-28 15:38:41.292' - DEBUG - Simulation time: 333.5352575609523
# 2025-08-28 15:38:41.305' - DEBUG - Simulation time: 334.63554342418826
# 2025-08-28 15:38:41.317' - DEBUG - Simulation time: 335.7792151659341
# 2025-08-28 15:38:41.329' - DEBUG - Simulation time: 337.1245515470955
# 2025-08-28 15:38:41.341' - DEBUG - Simulation time: 338.27964404750253
# 2025-08-28 15:38:41.354' - DEBUG - Simulation time: 339.4612427272119
# 2025-08-28 15:38:41.366' - DEBUG - Simulation time: 340.6008847169267
# 2025-08-28 15:38:41.378' - DEBUG - Simulation time: 341.720270143592
# 2025-08-28 15:38:41.390' - DEBUG - Simulation time: 342.9012713338202
# 2025-08-28 15:38:41.401' - DEBUG - Simulation time: 344.2683476061525
# 2025-08-28 15:38:41.414' - DEBUG - Simulation time: 345.56815763607693
# 2025-08-28 15:38:41.426' - DEBUG - Simulation time: 346.6603030856843
# 2025-08-28 15:38:41.439' - DEBUG - Simulation time: 347.8140889122464
# 2025-08-28 15:38:41.451' - DEBUG - Simulation time: 349.0460259428881
# 2025-08-28 15:38:41.462' - DEBUG - Simulation time: 350.34587542013134
# 2025-08-28 15:38:41.475' - DEBUG - Simulation time: 351.38561621239563
# 2025-08-28 15:38:41.488' - DEBUG - Simulation time: 352.4600030675742
# 2025-08-28 15:38:41.500' - DEBUG - Simulation time: 353.6532951993426
# 2025-08-28 15:38:41.512' - DEBUG - Simulation time: 354.8880545403155
# 2025-08-28 15:38:41.525' - DEBUG - Simulation time: 355.90482496008224
# 2025-08-28 15:38:41.538' - DEBUG - Simulation time: 357.2195291014515
# 2025-08-28 15:38:41.549' - DEBUG - Simulation time: 358.4062766756973
# 2025-08-28 15:38:41.562' - DEBUG - Simulation time: 359.5345728992619
# 2025-08-28 15:38:41.574' - DEBUG - Simulation time: 360.70134371320705
# 2025-08-28 15:38:41.587' - DEBUG - Simulation time: 361.7987743611967
# 2025-08-28 15:38:41.599' - DEBUG - Simulation time: 362.9547330305624
# 2025-08-28 15:38:41.611' - DEBUG - Simulation time: 364.2303655383556
# 2025-08-28 15:38:41.624' - DEBUG - Simulation time: 365.3364273790444
# 2025-08-28 15:38:41.637' - DEBUG - Simulation time: 366.51229462201377
# 2025-08-28 15:38:41.649' - DEBUG - Simulation time: 367.8225295559798
# 2025-08-28 15:38:41.662' - DEBUG - Simulation time: 368.993471638392
# 2025-08-28 15:38:41.675' - DEBUG - Simulation time: 370.2355173990552
# 2025-08-28 15:38:41.688' - DEBUG - Simulation time: 371.5197136835412
# 2025-08-28 15:38:41.701' - DEBUG - Simulation time: 372.6902152586312
# 2025-08-28 15:38:41.713' - DEBUG - Simulation time: 373.80075600421293
# 2025-08-28 15:38:41.725' - DEBUG - Simulation time: 375.01112382763506
# 2025-08-28 15:38:41.738' - DEBUG - Simulation time: 376.20546723317113
# 2025-08-28 15:38:41.750' - DEBUG - Simulation time: 377.39401859090367
# 2025-08-28 15:38:41.762' - DEBUG - Simulation time: 378.77556033003987
# 2025-08-28 15:38:41.774' - DEBUG - Simulation time: 379.89605575252955
# 2025-08-28 15:38:41.787' - DEBUG - Simulation time: 381.2140741236144
# 2025-08-28 15:38:41.799' - DEBUG - Simulation time: 382.3138364235098
# 2025-08-28 15:38:41.812' - DEBUG - Simulation time: 383.5352575609127
# 2025-08-28 15:38:41.824' - DEBUG - Simulation time: 384.63554342423964
# 2025-08-28 15:38:41.837' - DEBUG - Simulation time: 385.7792151657293
# 2025-08-28 15:38:41.859' - DEBUG - Simulation time: 387.1245515471587
# 2025-08-28 15:38:41.874' - DEBUG - Simulation time: 388.27964404717056
# 2025-08-28 15:38:41.886' - DEBUG - Simulation time: 389.4612427269319
# 2025-08-28 15:38:41.898' - DEBUG - Simulation time: 390.6008847169566
# 2025-08-28 15:38:41.910' - DEBUG - Simulation time: 391.72027014371554
# 2025-08-28 15:38:41.922' - DEBUG - Simulation time: 392.901271333793
# 2025-08-28 15:38:41.934' - DEBUG - Simulation time: 394.26834760596563
# 2025-08-28 15:38:41.946' - DEBUG - Simulation time: 395.5681576357954
# 2025-08-28 15:38:41.959' - DEBUG - Simulation time: 396.66030308556486
# 2025-08-28 15:38:41.971' - DEBUG - Simulation time: 397.8140889120578
# 2025-08-28 15:38:41.984' - DEBUG - Simulation time: 399.04602594322625
# 2025-08-28 15:38:41.996' - DEBUG - Simulation time: 400.3458754203179
# 2025-08-28 15:38:42.009' - DEBUG - Simulation time: 401.38561621254587
# 2025-08-28 15:38:42.021' - DEBUG - Simulation time: 402.46000306772
# 2025-08-28 15:38:42.034' - DEBUG - Simulation time: 403.65329519947045
# 2025-08-28 15:38:42.046' - DEBUG - Simulation time: 404.88805454041346
# 2025-08-28 15:38:42.059' - DEBUG - Simulation time: 405.90482495996554
# 2025-08-28 15:38:42.071' - DEBUG - Simulation time: 407.2195291013948
# 2025-08-28 15:38:42.082' - DEBUG - Simulation time: 408.4062766756273
# 2025-08-28 15:38:42.095' - DEBUG - Simulation time: 409.5345728993943
# 2025-08-28 15:38:42.107' - DEBUG - Simulation time: 410.7013437132013
# 2025-08-28 15:38:42.120' - DEBUG - Simulation time: 411.79877436109365
# 2025-08-28 15:38:42.132' - DEBUG - Simulation time: 412.95473303010533
# 2025-08-28 15:38:42.143' - DEBUG - Simulation time: 414.2303655381592
# 2025-08-28 15:38:42.156' - DEBUG - Simulation time: 415.3364273792168
# 2025-08-28 15:38:42.169' - DEBUG - Simulation time: 416.5122946220995
# 2025-08-28 15:38:42.182' - DEBUG - Simulation time: 417.8225295559203
# 2025-08-28 15:38:42.195' - DEBUG - Simulation time: 418.99347163836944
# 2025-08-28 15:38:42.208' - DEBUG - Simulation time: 420.23551739939967
# 2025-08-28 15:38:42.221' - DEBUG - Simulation time: 421.5197136838565
# 2025-08-28 15:38:42.234' - DEBUG - Simulation time: 422.6902152587522
# 2025-08-28 15:38:42.251' - DEBUG - Simulation time: 423.80075600436044
# 2025-08-28 15:38:42.267' - DEBUG - Simulation time: 425.0111238275776
# 2025-08-28 15:38:42.286' - DEBUG - Simulation time: 426.20546723318313
# 2025-08-28 15:38:42.298' - DEBUG - Simulation time: 427.3940185908443
# 2025-08-28 15:38:42.311' - DEBUG - Simulation time: 428.77556033024456
# 2025-08-28 15:38:42.323' - DEBUG - Simulation time: 429.89605575242376
# 2025-08-28 15:38:42.336' - DEBUG - Simulation time: 431.21407412347224
# 2025-08-28 15:38:42.348' - DEBUG - Simulation time: 432.3138364237042
# 2025-08-28 15:38:42.360' - DEBUG - Simulation time: 433.5352575610062
# 2025-08-28 15:38:42.372' - DEBUG - Simulation time: 434.63554342421327
# 2025-08-28 15:38:42.383' - DEBUG - Simulation time: 435.7792151658289
# 2025-08-28 15:38:42.394' - DEBUG - Simulation time: 437.12455154700945
# 2025-08-28 15:38:42.406' - DEBUG - Simulation time: 438.2796440473522
# 2025-08-28 15:38:42.417' - DEBUG - Simulation time: 439.46124272709653
# 2025-08-28 15:38:42.429' - DEBUG - Simulation time: 440.60088471700755
# 2025-08-28 15:38:42.440' - DEBUG - Simulation time: 441.72027014405495
# 2025-08-28 15:38:42.452' - DEBUG - Simulation time: 442.90127133376814
# 2025-08-28 15:38:42.463' - DEBUG - Simulation time: 444.26834760616674
# 2025-08-28 15:38:42.475' - DEBUG - Simulation time: 445.56815763582694
# 2025-08-28 15:38:42.487' - DEBUG - Simulation time: 446.66030308570174
# 2025-08-28 15:38:42.499' - DEBUG - Simulation time: 447.81408891232036
# 2025-08-28 15:38:42.511' - DEBUG - Simulation time: 449.04602594302787
# 2025-08-28 15:38:42.523' - DEBUG - Simulation time: 450.34587542031164
# 2025-08-28 15:38:42.534' - DEBUG - Simulation time: 451.38561621242843
# 2025-08-28 15:38:42.546' - DEBUG - Simulation time: 452.460003067686
# 2025-08-28 15:38:42.557' - DEBUG - Simulation time: 453.6532951994143
# 2025-08-28 15:38:42.569' - DEBUG - Simulation time: 454.8880545403786
# 2025-08-28 15:38:42.581' - DEBUG - Simulation time: 455.9048249600491
# 2025-08-28 15:38:42.655' - DEBUG - Simulation time: 457.2195291013303
# 2025-08-28 15:38:42.682' - DEBUG - Simulation time: 458.4062766754855
# 2025-08-28 15:38:42.693' - DEBUG - Simulation time: 459.53457289945635
# 2025-08-28 15:38:42.705' - DEBUG - Simulation time: 460.7013437133002
# 2025-08-28 15:38:42.717' - DEBUG - Simulation time: 461.7987743611689
# 2025-08-28 15:38:42.728' - DEBUG - Simulation time: 462.9547330304432
# 2025-08-28 15:38:42.739' - DEBUG - Simulation time: 464.23036553851244
# 2025-08-28 15:38:42.751' - DEBUG - Simulation time: 465.33642737925913
# 2025-08-28 15:38:42.763' - DEBUG - Simulation time: 466.5122946220667
# 2025-08-28 15:38:42.775' - DEBUG - Simulation time: 467.82252955599347
# 2025-08-28 15:38:42.786' - DEBUG - Simulation time: 468.99347163853287
# 2025-08-28 15:38:42.798' - DEBUG - Simulation time: 470.2355173991354
# 2025-08-28 15:38:42.809' - DEBUG - Simulation time: 471.51971368343106
# 2025-08-28 15:38:42.822' - DEBUG - Simulation time: 472.6902152588861
# 2025-08-28 15:38:42.836' - DEBUG - Simulation time: 473.8007560044081
# 2025-08-28 15:38:42.853' - DEBUG - Simulation time: 475.01112382781116
# 2025-08-28 15:38:42.865' - DEBUG - Simulation time: 476.20546723320206
# 2025-08-28 15:38:42.877' - DEBUG - Simulation time: 477.3940185909777
# 2025-08-28 15:38:42.889' - DEBUG - Simulation time: 478.7755603302008
# 2025-08-28 15:38:42.901' - DEBUG - Simulation time: 479.89605575250505
# 2025-08-28 15:38:42.912' - DEBUG - Simulation time: 481.2140741235461
# 2025-08-28 15:38:42.924' - DEBUG - Simulation time: 482.3138364235969
# 2025-08-28 15:38:42.936' - DEBUG - Simulation time: 483.535257560852
# 2025-08-28 15:38:42.947' - DEBUG - Simulation time: 484.6355434241976
# 2025-08-28 15:38:42.959' - DEBUG - Simulation time: 485.7792151659473
# 2025-08-28 15:38:42.970' - DEBUG - Simulation time: 487.1245515470168
# 2025-08-28 15:38:42.982' - DEBUG - Simulation time: 488.2796440473465
# 2025-08-28 15:38:42.993' - DEBUG - Simulation time: 489.46124272742435
# 2025-08-28 15:38:43.004' - DEBUG - Simulation time: 490.60088471675505
# 2025-08-28 15:38:43.016' - DEBUG - Simulation time: 491.7202701437977
# 2025-08-28 15:38:43.027' - DEBUG - Simulation time: 492.901271333595
# 2025-08-28 15:38:43.039' - DEBUG - Simulation time: 494.2683476061418
# 2025-08-28 15:38:43.050' - DEBUG - Simulation time: 495.56815763580596
# 2025-08-28 15:38:43.061' - DEBUG - Simulation time: 496.6603030855118
# 2025-08-28 15:38:43.072' - DEBUG - Simulation time: 497.8140889122082
# 2025-08-28 15:38:43.084' - DEBUG - Simulation time: 499.04602594306317
# 2025-08-28 15:38:43.095' - DEBUG - Simulation time: 500.34587542063576

# %%
from rsnn.metrics import compute_similarities

# %%
similarities = []

for i in range(0, 10):
    spikes_window = spikes_sim.filter(
        pl.col("time").is_between(i * period, (i + 1) * period, closed="left")
    )
    shifts = (
        spikes_window.join(spikes_ref, on="neuron", suffix="_ref")
        .select((pl.col("time_ref") - pl.col("time")).round(3).alias("delta"))
        .unique()
        .filter(pl.col("delta").is_between(-1.0 - i * period, 1.0 - i * period))
    )
    precisions, recalls = compute_similarities(
        spikes_window, spikes_ref, shifts, n_neurons
    )
    best_precision = precisions.top_k(1, by="meas_precision")
    best_recall = recalls.top_k(1, by="meas_recall")

    similarities.append(
        pl.DataFrame({"cycle": [i]})
        .join(best_precision, how="cross")
        .join(best_recall, how="cross")
    )
similarities = pl.concat(similarities).sort("cycle")
similarities,
# Out:
# (shape: (10, 5)
#  ┌───────┬─────────────────┬────────────────┬──────────────┬─────────────┐
#  │ cycle ┆ delta_precision ┆ meas_precision ┆ delta_recall ┆ meas_recall │
#  │ ---   ┆ ---             ┆ ---            ┆ ---          ┆ ---         │
#  │ i64   ┆ f64             ┆ f64            ┆ f64          ┆ f64         │
#  ╞═══════╪═════════════════╪════════════════╪══════════════╪═════════════╡
#  │ 0     ┆ -0.0            ┆ 1.0            ┆ -0.0         ┆ 1.0         │
#  │ 1     ┆ -50.0           ┆ 1.0            ┆ -50.0        ┆ 1.0         │
#  │ 2     ┆ -100.0          ┆ 1.0            ┆ -100.0       ┆ 1.0         │
#  │ 3     ┆ -150.0          ┆ 1.0            ┆ -150.0       ┆ 1.0         │
#  │ 4     ┆ -200.0          ┆ 1.0            ┆ -200.0       ┆ 1.0         │
#  │ 5     ┆ -250.0          ┆ 1.0            ┆ -250.0       ┆ 1.0         │
#  │ 6     ┆ -300.0          ┆ 1.0            ┆ -300.0       ┆ 1.0         │
#  │ 7     ┆ -350.0          ┆ 1.0            ┆ -350.0       ┆ 1.0         │
#  │ 8     ┆ -400.0          ┆ 1.0            ┆ -400.0       ┆ 1.0         │
#  │ 9     ┆ -450.0          ┆ 1.0            ┆ -450.0       ┆ 1.0         │
#  └───────┴─────────────────┴────────────────┴──────────────┴─────────────┘,)

# %%
raise ValueError("STOP")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 raise ValueError("STOP")
#
# ValueError: STOP

# %% [markdown]
# # Visualizations for the thesis
#
# - Weight distributions
# - Number of violations vs iterations
# - Constraints correlations in the weights norm

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
res = ax.hist(syn_weights.X, bins=100, density=True)
res = ax.set_xlabel("weight")
res = ax.set_ylabel("frequency")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot(111)
# ----> 3 res = ax.hist(syn_weights.X, bins=100, density=True)
#       4 res = ax.set_xlabel("weight")
#       5 res = ax.set_ylabel("frequency")
#
# NameError: name 'syn_weights' is not defined

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
res = stats.probplot(syn_weights.X, plot=ax)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

slack = np.array(model.getAttr("Slack"))
res = ax.hist(np.abs(slack), bins=100, density=True)
res = ax.set_xlabel("slack")
res = ax.set_ylabel("frequency")

# %%
A = model.getA()
W = A @ A.T

std_diag = np.sqrt(W.diagonal())
correlation_matrix = W / (std_diag[:, np.newaxis] * std_diag[np.newaxis, :])
correlation_matrix = correlation_matrix.todense()
fig = plt.figure()
ax = fig.add_subplot(111)

plt.imshow(correlation_matrix, cmap='RdBu', aspect='auto', vmin=-1, vmax=1)
# plt.imshow(neuron.solver.Wbxt_N, cmap='RdBu', aspect='auto', vmin=-np.max(np.abs(neuron.solver.Wbxt_N)), vmax=np.max(np.abs(neuron.solver.Wbxt_N)))
plt.colorbar(label='Correlation Value', ax=ax)
# plt.title('Constraint Correlations (Wbxt_N)')
# plt.xlabel('Constraint Index')
# plt.ylabel('Constraint Index')
# plt.show()

# %% [markdown]
# # Input Signals

# %%
n_in_channels = 6
n_in_times = 20
f_thresh = FIRING_THRESHOLD
zmax, dzmin = 0.0, 1e-2
eps = 0.5
f_time = 5.0
in_times = np.random.uniform(0.0, f_time, size=n_in_times)
in_channels = (np.random.randint(0, n_in_channels, size=n_in_times))

# %%
start, length, ck0, ck1 = compute_ck(
    in_times,
    in_channels,
    n_in_channels,
    np.array([f_time, f_time-eps]),
    REFRACTORY_RESET
)

# %%
fig, axes = plt.subplots(3, 1, figsize=(6, 5), sharex=True, height_ratios=(5, 5, 1))

for (in_time, in_channel) in zip(in_times, in_channels):
    axes[2].axvline(in_time, color=f'C{in_channel}')

for i in range(3):
    axes[i].axvline(f_time - eps, color=f'black', linewidth=0.5, linestyle='--', label='_nolegend_')

axes[2].set_xlabel('t')
axes[0].set_title('Per Input Channel Signals')
# axes[2].set_ylabel('Spikes')
axes[2].set_yticks([])
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
axes[2].grid(True, alpha=0.3)
axes[2].set_xlim(0, f_time)

for start_n, length_n, ck0_n, ck1_n in zip(start, length, ck0, ck1):
    # for k in range(neuron.n_in_channels):
    for k in range(n_in_channels):
        dt_vals = np.arange(0, length_n, 1e-2)
        t_vals = dt_vals + start_n
        y_vals = (ck0_n[k] + ck1_n[k] * dt_vals) * np.exp(-dt_vals)
        axes[0].plot(t_vals, y_vals, c=f"C{k}", linewidth=1.5)

        y_vals = (ck1_n[k] - ck0_n[k] - ck1_n[k] * dt_vals) * np.exp(-dt_vals)
        axes[1].plot(t_vals, y_vals, c=f"C{k}", linewidth=1.5)

axes[1].legend([f"ch. {k+1}" for k in range(n_in_channels)], bbox_to_anchor=(1.05, 0.5), loc='center left', ncol=1)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Iterative Constraint Refinement

# %%
def plot_tvc(ax, tc, vc):
    ax.axvline(
        tc,
        color="C1",
        linestyle="--",
        linewidth=1,
        alpha=0.5,
        label=rf"$t_c={tc:.2f}$",
    )
    ax.scatter(tc, vc, color="C1", s=30)
    ax.legend()

def plot_z_template(neuron, ax, f_time, eps, f_thresh, zmax):
    for start, length, c0, c1 in zip(
        neuron.z_start, neuron.z_length, neuron.z_c0, neuron.z_c1
    ):
        dt_vals = np.arange(0, length, 1e-3)
        t_vals = dt_vals + start
        y_vals = (c0 + c1 * dt_vals) * np.exp(-dt_vals)
        ax.plot(t_vals, y_vals, linewidth=1.5, c="C0", label="__nolegend_")

    ax.plot(
        np.array([0, f_time - eps]),
        np.full(2,zmax),
        color="C3",
        label="__nolegend_",
    )
    ax.plot(
        np.array([f_time - eps, f_time]),
        np.full(2,f_thresh),
        color="C3",
        label="__nolegend_",
    )

def plot_dz_template(neuron, ax, f_time, eps, dzmin):
    for start, length, c0, c1 in zip(
        neuron.dz_start, neuron.dz_length, neuron.dz_c0, neuron.dz_c1
    ):
        dt_vals = np.arange(0, length, 1e-3)
        t_vals = dt_vals + start
        y_vals = (c0 + c1 * dt_vals) * np.exp(-dt_vals)
        ax.plot(t_vals, -y_vals, linewidth=1.5, c="C0", label="__nolegend_")

    ax.plot(
        np.array([f_time - eps, f_time]),
        np.full(2,dzmin),
        color="C3",
        label="__nolegend_",
    )

# %%
n_in_channels = 20
n_in_times = 25
f_thresh = 1.0
zmax, dzmin = 0.0, 0.5
eps = 0.5
period = 10.0
f_time = 0.0
in_times = np.random.uniform(0.0, period, size=n_in_times)
in_channels = (np.random.randint(0, n_in_channels, size=n_in_times))

# %%
neuron = Neuron()
feas_tol, conv_tol = 1e-2, 1e-12
n_iter = 8

neuron.init_solver(
    np.array([f_time]),
    in_times,
    in_channels,
    period=period,
    eps=eps,
    zmax=zmax,
    dzmin=dzmin,
    f_thresh=f_thresh,
)

fig, axes = plt.subplots(
    2 * n_iter,
    2,
    figsize=(5.1, 1.8 * (n_iter)),
    sharex=True,
    height_ratios=(1, 0.2) * n_iter,
    layout="constrained",
    gridspec_kw={"hspace": 0.07, "wspace": 0.05},
)

# axes[-1][0].set_xlim(0, 10.0)

# axes[0][1].set_title("Potential Derivative")
# axes[-1][1].set_xlim(0, 10.0)

for i in range(n_iter):
    axes[2*i][0].set_title(f"\n Iter {i+1} - Potential")
    axes[2*i][1].set_title(f"\n Iter {i+1} - Potential Derivative")
    axes[2*i][0].grid(True, alpha=0.3)
    axes[2*i][1].grid(True, alpha=0.3)
    axes[2*i][0].set_ylim(-2, 2)
    axes[2*i][1].set_ylim(-1, 3.0)
    axes[2*i][0].set_xticklabels([])
    axes[2*i][0].set_yticklabels([])
    axes[2*i][1].set_xticklabels([])
    axes[2*i][1].set_yticklabels([])

    axes[2*i+1][0].grid(True, alpha=0.3)
    axes[2*i+1][1].grid(True, alpha=0.3)
    axes[2*i+1][0].set_xticklabels([])
    axes[2*i+1][0].set_yticklabels([])
    axes[2*i+1][1].set_xticklabels([])
    axes[2*i+1][1].set_yticklabels([])

    axes[2*i+1][0].set_xlabel("time")
    axes[2*i+1][1].set_xlabel("time")

    axes[2*i+1][0].scatter(in_times, np.zeros_like(in_times), s=10, color="black", label="_nolegend_")
    axes[2*i+1][1].scatter(in_times, np.zeros_like(in_times), s=10, color="black", label="_nolegend_")

for i in range(n_iter):
    res_dcd = neuron.solver.dbffd(feas_tol, conv_tol)
    if res_dcd == 1:
        neuron.z_c0 = (
            np.inner(neuron.z_ck0[:, :-1], neuron.solver.x) + neuron.z_ck0[:, -1]
        )
        neuron.z_c1 = (
            np.inner(neuron.z_ck1[:, :-1], neuron.solver.x) + neuron.z_ck1[:, -1]
        )
        plot_z_template(neuron, axes[2*i][0], period, eps, f_thresh, zmax)
        
        neuron.dz_c0 = (
            np.inner(neuron.dz_ck0[:, :-1], neuron.solver.x) + neuron.dz_ck0[:, -1]
        )
        neuron.dz_c1 = (
            np.inner(neuron.dz_ck1[:, :-1], neuron.solver.x) + neuron.dz_ck1[:, -1]
        )
        plot_dz_template(neuron, axes[2*i][1], period, eps, dzmin)

        z_imax, z_vmax, z_dtmax = find_maximum_violation(
            neuron.z_c0, neuron.z_c1, neuron.z_length, neuron.z_lim
        )

        dz_imax, dz_vmax, dz_dtmax = find_maximum_violation(
            neuron.dz_c0, neuron.dz_c1, neuron.dz_length, neuron.dz_lim
        )

        if z_vmax <= feas_tol and dz_vmax <= feas_tol:
            print(f"Optimal solution found in {i+1} iterations.")
            break
        else:
            if z_vmax > dz_vmax:
                neuron.solver.add_constraint(
                    (neuron.z_ck0[z_imax, :-1] + z_dtmax * neuron.z_ck1[z_imax, :-1])
                    * np.exp(-z_dtmax),
                    neuron.z_lim[z_imax]
                    - (neuron.z_ck0[z_imax, -1] + z_dtmax * neuron.z_ck1[z_imax, -1])
                    * np.exp(-z_dtmax),
                )
                plot_tvc(
                    axes[2*i][0],
                    neuron.z_start[z_imax] + z_dtmax,
                    z_vmax + neuron.z_lim[z_imax],
                )

            else:
                neuron.solver.add_constraint(
                    (
                        neuron.dz_ck0[dz_imax, :-1]
                        + dz_dtmax * neuron.dz_ck1[dz_imax, :-1]
                    )
                    * np.exp(-dz_dtmax),
                    neuron.dz_lim[dz_imax]
                    - (
                        neuron.dz_ck0[dz_imax, -1]
                        + dz_dtmax * neuron.dz_ck1[dz_imax, -1]
                    )
                    * np.exp(-dz_dtmax),
                )
                plot_tvc(
                    axes[2*i][1],
                    neuron.dz_start[dz_imax] + dz_dtmax,
                    -dz_vmax - neuron.dz_lim[dz_imax],
                )
    else:
        break

plt.legend()
# plt.tight_layout()
plt.show()
# Out:
# Converged after 2 iterations
# Feasible solution found with cost 1.2090952822652663.
# Converged after 4 iterations
# Feasible solution found with cost 2.2763077970923473.
# Converged after 3 iterations
# Feasible solution found with cost 2.4013807716151505.
# Converged after 4 iterations
# Feasible solution found with cost 3.330631692456987.
# Converged after 3 iterations
# Feasible solution found with cost 3.367143368154999.
# Converged after 3 iterations
# Feasible solution found with cost 3.378006594473695.
# Converged after 4 iterations
# Feasible solution found with cost 3.3880465970777514.
# Converged after 4 iterations
# Feasible solution found with cost 3.3934949246134836.
# Optimal solution found in 8 iterations.
# /Users/haguettaz/Desktop/RSNN/src/rsnn/optim.py:108: RuntimeWarning: divide by zero encountered in divide
#   ts = np.where(c1 <= 0, 0.0, np.clip(1 - c0 / c1, 0.0, length))
# /var/folders/p1/wl8__y5x6jgfhz_d47k5gq9m0000gn/T/ipykernel_10368/3281605761.py:123: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # `Neuron.learn()`

# %%
# def plot_z_template(neuron, ax, f_time, eps, f_thresh, zmax):
#     for start, length, c0, c1 in zip(
#         neuron.z_start, neuron.z_length, neuron.z_c0, neuron.z_c1
#     ):
#         dt_vals = np.arange(0, length, 1e-2)
#         t_vals = dt_vals + start
#         y_vals = (c0 + c1 * dt_vals) * np.exp(-dt_vals)
#         ax.plot(t_vals, y_vals, linewidth=1.5, c="C0", label="__nolegend_")

#     ax.plot(
#         np.array([0, f_time - eps]),
#         np.full(2,zmax),
#         color="C4",
#         label="__nolegend_",
#     )
#     ax.plot(
#         np.array([f_time - eps, f_time]),
#         np.full(2,f_thresh),
#         color="C4",
#         label="__nolegend_",
#     )

# def plot_dz_template(neuron, ax, f_time, eps, dzmin):
#     for start, length, c0, c1 in zip(
#         neuron.dz_start, neuron.dz_length, neuron.dz_c0, neuron.dz_c1
#     ):
#         dt_vals = np.arange(0, length, 1e-2)
#         t_vals = dt_vals + start
#         y_vals = (c0 + c1 * dt_vals) * np.exp(-dt_vals)
#         ax.plot(t_vals, -y_vals, linewidth=1.5, c="C0", label="__nolegend_")

#     ax.plot(
#         np.array([f_time - eps, f_time]),
#         np.full(2,dzmin),
#         color="C4",
#         label="__nolegend_",
#     )

# %%
n_neurons = 100
n_in_channels = 1000
period = 1000.0
f_rate = 0.5

f_times = rand_f_times(n_neurons, period, f_rate)
in_delays = np.random.uniform(0.0, 20.0, size=n_in_channels)
in_sources = np.random.randint(0, n_neurons, size=n_in_channels)

in_times = np.concatenate(
        [
            f_times[in_src] + in_delay
            for in_src, in_delay in zip(in_sources, in_delays)
        ]
    )
in_channels = np.concatenate(
    [
        np.full(f_times[in_src].size, in_channel, dtype=np.intp)
        for in_channel, in_src in enumerate(in_sources)
    ]
)
f_times_0 = np.sort((f_times[0]))
f_times_0 -= f_times_0[0]
f_times_0 = np.append(f_times_0, period)

# %%
neuron = Neuron()

neuron.init_solver(
        np.copy(f_times_0[:-1]),
        in_times,
        in_channels,
        period=period,
        eps=0.2,
        zmax=0.0,
        dzmin=2.0,
    )
print("Starting learning...")
neuron.learn()
# Out:
# Starting learning...
# Converged after 10 iterations
# Feasible solution found with cost 0.5143628939230912.
# Iteration 1: 272 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 0.822030530954598.
# Iteration 2: 273 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 1.0495893624233101.
# Iteration 3: 274 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 1.4289862584817024.
# Iteration 4: 275 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 1.6780464557491928.
# Iteration 5: 276 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 1.7791325562547073.
# Iteration 6: 277 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 1.9721734811944258.
# Iteration 7: 278 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 2.2045306491367738.
# Iteration 8: 279 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 2.2656959595897708.
# Iteration 9: 280 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 2.3539107775014867.
# Iteration 10: 281 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 2.4146295168352414.
# Iteration 11: 282 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 2.4610787650199737.
# Iteration 12: 283 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 2.5102352887564634.
# Iteration 13: 284 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 2.5853971282294608.
# Iteration 14: 285 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 2.6424238983065313.
# Iteration 15: 286 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 2.700611176379099.
# Iteration 16: 287 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 2.756475817788003.
# Iteration 17: 288 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 2.805064039129996.
# Iteration 18: 289 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 2.8802870693633036.
# Iteration 19: 290 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 2.9238495386482635.
# Iteration 20: 291 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 2.9994233069151166.
# Iteration 21: 292 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 3.0497016275612787.
# Iteration 22: 293 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 3.0961956076613095.
# Iteration 23: 294 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 3.2288369370035066.
# Iteration 24: 295 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 3.2713181516871765.
# Iteration 25: 296 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 3.311597305920989.
# Iteration 26: 297 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 3.375672978008603.
# Iteration 27: 298 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 3.4430189677151724.
# Iteration 28: 299 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 3.5036390181176613.
# Iteration 29: 300 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 3.547736005348945.
# Iteration 30: 301 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 3.5964874122906165.
# Iteration 31: 302 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 3.646847349048047.
# Iteration 32: 303 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 3.7194613245461.
# Iteration 33: 304 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 3.764197290574838.
# Iteration 34: 305 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 3.8077646862218093.
# Iteration 35: 306 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 3.8464005894668944.
# Iteration 36: 307 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 3.8933497859420965.
# Iteration 37: 308 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 3.937763665404041.
# Iteration 38: 309 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 3.9848821496694615.
# Iteration 39: 310 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 4.029768130950083.
# Iteration 40: 311 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 4.171409158577856.
# Iteration 41: 312 constraints.
# Converged after 4 iterations
# Feasible solution found with cost 4.208766318993141.
# Iteration 42: 313 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 4.252748246010483.
# Iteration 43: 314 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 4.307897601392597.
# Iteration 44: 315 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 4.348941914020733.
# Iteration 45: 316 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 4.392573049686379.
# Iteration 46: 317 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 4.4311278244909245.
# Iteration 47: 318 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 4.48839350785686.
# Iteration 48: 319 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 4.548481153405121.
# Iteration 49: 320 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 4.595002228805457.
# Iteration 50: 321 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 4.632659767719712.
# Iteration 51: 322 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 4.677416610676981.
# Iteration 52: 323 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 4.722067324411291.
# Iteration 53: 324 constraints.
# Converged after 6 iterations
# Feasible solution found with cost 4.766972709388215.
# Iteration 54: 325 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 4.806350688228539.
# Iteration 55: 326 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 4.8444789929712115.
# Iteration 56: 327 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 4.890721953802177.
# Iteration 57: 328 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 4.92555688416192.
# Iteration 58: 329 constraints.
# Converged after 6 iterations
# Feasible solution found with cost 5.0221270253275305.
# Iteration 59: 330 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 5.058511423952693.
# Iteration 60: 331 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 5.096041680527078.
# Iteration 61: 332 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 5.137018481732656.
# Iteration 62: 333 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 5.190587946530123.
# Iteration 63: 334 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 5.228825778326898.
# Iteration 64: 335 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 5.267492202222373.
# Iteration 65: 336 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 5.32837450055991.
# Iteration 66: 337 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 5.418295185235029.
# Iteration 67: 338 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 5.45102499075994.
# Iteration 68: 339 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 5.501452293189204.
# Iteration 69: 340 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 5.53531585594291.
# Iteration 70: 341 constraints.
# Converged after 6 iterations
# Feasible solution found with cost 5.580753376112201.
# Iteration 71: 342 constraints.
# Converged after 5 iterations
# Feasible solution found with cost 5.622230333288705.
# Iteration 72: 343 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 5.655134801022874.
# Iteration 73: 344 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 5.687091830144311.
# Iteration 74: 345 constraints.
# Converged after 11 iterations
# Feasible solution found with cost 5.741608699219077.
# Iteration 75: 346 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 5.779070891010366.
# Iteration 76: 347 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 5.819692952387621.
# Iteration 77: 348 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 5.885592093806495.
# Iteration 78: 349 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 5.919122040083852.
# Iteration 79: 350 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 5.95307932856795.
# Iteration 80: 351 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 6.036898740424873.
# Iteration 81: 352 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 6.091715834612331.
# Iteration 82: 353 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 6.129060553923635.
# Iteration 83: 354 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 6.165054330405969.
# Iteration 84: 355 constraints.
# Converged after 11 iterations
# Feasible solution found with cost 6.200901495812894.
# Iteration 85: 356 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 6.240528905860166.
# Iteration 86: 357 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 6.281499958633483.
# Iteration 87: 358 constraints.
# Converged after 11 iterations
# Feasible solution found with cost 6.319425094807516.
# Iteration 88: 359 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 6.35989729756299.
# Iteration 89: 360 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 6.404837184230065.
# Iteration 90: 361 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 6.474097956346559.
# Iteration 91: 362 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 6.5489214682095325.
# Iteration 92: 363 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 6.5966772847565744.
# Iteration 93: 364 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 6.6465969819874795.
# Iteration 94: 365 constraints.
# Converged after 12 iterations
# Feasible solution found with cost 6.761575352217224.
# Iteration 95: 366 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 6.804796727994519.
# Iteration 96: 367 constraints.
# Converged after 7 iterations
# Feasible solution found with cost 6.8540563179194605.
# Iteration 97: 368 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 6.897826422224825.
# Iteration 98: 369 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 6.936019758783822.
# Iteration 99: 370 constraints.
# Converged after 9 iterations
# Feasible solution found with cost 7.014541938233353.
# Iteration 100: 371 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 7.067122911414181.
# Iteration 101: 372 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 7.138511034034042.
# Iteration 102: 373 constraints.
# Converged after 10 iterations
# Feasible solution found with cost 7.220385286657746.
# Iteration 103: 374 constraints.
# Converged after 8 iterations
# Feasible solution found with cost 7.32195954901463.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 13
#       3 neuron.init_solver(
#       4         np.copy(f_times_0[:-1]),
#       5         in_times,
#    (...)     10         dzmin=2.0,
#      11     )
#      12 print("Starting learning...")
# ---> 13 neuron.learn()
#
# File ~/Desktop/RSNN/src/rsnn/optim.py:650, in Neuron.learn(self, feas_tol, conv_tol, n_cstrs, n_dcd_iter)
#     647     return res_dcd
#     649 # 2. Refine constraints based on the current primal solution. If no constraints are violated, then the primal solution is optimal.
# --> 650 res_refine = self.refine_constraints(feas_tol)
#     651 if res_refine == 0:
#     652     print(f"Iteration {i+1}: {self.solver.n_cstrs} constraints.")
#
# File ~/Desktop/RSNN/src/rsnn/optim.py:567, in refine_constraints(self, feas_tol)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(
    3,
    figsize=(12, 4),
    height_ratios=(1, 1, 0.2),
    sharex=True,
)

axes[0].set_xlim(f_times_0[0], f_times_0[-1])
axes[2].set_xlabel("time")
axes[0].set_ylabel("potential")
axes[1].set_ylabel("potential\nderivative")
axes[2].set_ylabel("input \nspikes")
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
axes[2].grid(True, alpha=0.3)

axes[0].set_xticklabels([])
axes[0].set_yticklabels([])
axes[1].set_xticklabels([])
axes[1].set_yticklabels([])
axes[2].set_xticklabels([])
axes[2].set_yticklabels([])

for start, length, c0, c1, lim in zip(
    neuron.z_start, neuron.z_length, neuron.z_c0, neuron.z_c1, neuron.z_lim
):
    dt_vals = np.arange(0, length, 1e-3)
    t_vals = dt_vals + start
    y_vals = (c0 + c1 * dt_vals) * np.exp(-dt_vals)
    axes[0].plot(t_vals, y_vals, linewidth=1.5, c="C0", label="__nolegend_")
    axes[0].plot(t_vals, np.full_like(t_vals, lim), c="C3", label="__nolegend_")

for start, length, c0, c1, lim in zip(
    neuron.dz_start, neuron.dz_length, neuron.dz_c0, neuron.dz_c1, neuron.dz_lim
):
    dt_vals = np.arange(0, length, 1e-3)
    t_vals = dt_vals + start
    y_vals = (c0 + c1 * dt_vals) * np.exp(-dt_vals)
    axes[1].plot(t_vals, -y_vals, linewidth=1.5, c="C0", label="__nolegend_")
    axes[1].plot(t_vals, np.full_like(t_vals, -lim), c="C3", label="__nolegend_")

axes[0].scatter(f_times_0[1:], np.full_like(f_times_0[1:], FIRING_THRESHOLD), marker="x", s=20, c="C2")

axes[2].scatter(in_times % period, np.zeros_like(in_times), s=5, color="black", label="_nolegend_", alpha=0.03)

# plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(neuron.weight, bins=30, alpha=0.7, edgecolor='black')
plt.xlabel('Weight Value')
plt.ylabel('Frequency')
plt.title('Distribution of Neuron Weights')
plt.grid(True, alpha=0.3)
plt.show()

# %%
n_in_channels = 500
n_in_times = 1000
f_thresh = 1.0
zmax, dzmin = 0.0, 1.0
eps = 0.5
period = 10.0
f_time = 0.0
in_times = np.random.uniform(0.0, period, size=n_in_times)
in_channels = (np.random.randint(0, n_in_channels, size=n_in_times))

neuron = optim.Neuron()
neuron.init_solver(
        np.array([f_time]),
        in_times,
        in_channels,
        period=period,
        eps=eps,
        zmax=zmax,
        dzmin=dzmin,
        f_thresh=f_thresh
    )
neuron.learn()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 11
#       8 in_times = np.random.uniform(0.0, period, size=n_in_times)
#       9 in_channels = (np.random.randint(0, n_in_channels, size=n_in_times))
# ---> 11 neuron = optim.Neuron()
#      12 neuron.init_solver(
#      13         np.array([f_time]),
#      14         in_times,
#    (...)     20         f_thresh=f_thresh
#      21     )
#      22 neuron.learn()
#
# NameError: name 'optim' is not defined

# %% [markdown]
# # Determining the critical points

# %%
in_coef = np.random.randn(2, 5, 10) / np.sqrt(10)  # shape (2, n_inputs, n_intervals)
ends = np.random.uniform(0, 5, size=5)  # shape (n_intervals,)
weights = np.random.randn(10)  # shape (n_inputs,)
zmax = 0.0  # some threshold value
coef = np.inner(in_coef, weights)  # shape (2, n_intervals)

imax, tmax, vmax = critical_potential(coef, ends, zmax)

fig, axes = plt.subplots(1, 5, figsize=(15, 3), sharey=True)

for i in range(5):
    t_vals = np.linspace(0, ends[i], 1000)
    y_vals = (coef[0, i] + coef[1, i] * t_vals) * np.exp(-t_vals)
    
    axes[i].plot(t_vals, y_vals, 'b-', linewidth=2)
    axes[i].axhline(y=zmax, color='r', linestyle='--', alpha=0.7, label=f'zmax={zmax}')
    axes[i].set_xlabel('t')
    axes[i].set_ylabel('Signal')
    axes[i].set_title(f'Interval {i+1}')
    axes[i].grid(True, alpha=0.3)
    # axes[i].set_xlim(0, ends[i])
    axes[i].legend()

axes[imax].axvline(tmax, color='black', linestyle='--', label=f'tmax={tmax:.2f}, vmax={vmax:.2f}')
axes[imax].legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       4 zmax = 0.0  # some threshold value
#       5 coef = np.inner(in_coef, weights)  # shape (2, n_intervals)
# ----> 7 imax, tmax, vmax = critical_potential(coef, ends, zmax)
#       9 fig, axes = plt.subplots(1, 5, figsize=(15, 3), sharey=True)
#      11 for i in range(5):
#
# NameError: name 'critical_potential' is not defined

# %%
coef[:, 2]
ts = np.clip(1 - coef[0,2] / coef[1,2], 0.0, ends[2])  # t = 1 - c0 / c1, the clipping also handles the case c1 = 0
vs = np.maximum(coef[0,2], (coef[0,2] + coef[1,2] * ts) * np.exp(-ts))
ts, vs
# Out:
# (np.float64(0.02153725776080251), np.float64(2.03236525539423))

# %%
a = ((in_coef[0, imax] + tmax * in_coef[1, imax]) * np.exp(-tmax)).reshape(1, -1)
b = np.array([zmax])

# %%
from dataclasses import dataclass


@dataclass
class InSpike:
    conn_id: int
    time: float


period = 100.0

n_f_times = 3
f_times = np.random.uniform(0, 100, size=n_f_times)
f_times = np.sort(f_times)
s0 = f_times[0]
# f_times = np.concatenate(
#     (np.array([f_times[-1] - period]), f_times, np.array([f_times[0] + period]))
# )
f_times -= s0
starts = np.append(f_times, period)
# ends = np.roll(f_times, -1)
# ends[-1] = period
f_times, starts
# Out:
# (array([ 0.        , 38.60756882, 50.88000478]),
#  array([  0.        ,  38.60756882,  50.88000478, 100.        ]))

# %%
# note: make sure in_spikes are in [0, period]
n_inputs = 6
n_in_spikes = 5
in_spikes = [
    InSpike(conn_id=np.random.randint(0, n_inputs), time=np.random.uniform(0, period))
    for _ in range(n_in_spikes)
] 
in_spikes.sort(key=lambda x: x.time)
in_ids = np.array([spike.conn_id for spike in in_spikes])
in_times = np.array([spike.time for spike in in_spikes])
# in_times = np.array([(spike.time - s0) % period for spike in in_spikes])

# find the interval indices for each input spike time
in_int = np.searchsorted(starts, in_times, side='right') - 1

in_times, starts
# Out:
# (array([ 2.6875488 ,  6.16243931, 53.41486702, 63.2614007 , 81.01977437]),
#  array([  0.        ,  38.60756882,  50.88000478, 100.        ]))

# %%
# correspond to the first interval, now needs to compute the subintervals
in_times[in_int == 0], in_ids[in_int == 0], starts[0], starts[1]
# Out:
# (array([2.6875488 , 6.16243931]),
#  array([4, 1]),
#  np.float64(0.0),
#  np.float64(38.60756882432332))

# %%
# we first consider only one interval (0, s] where s is the desired firing time
# assume the neuron receives n_in_spikes spikes from n_inputs inputs during the interval [0, s)
# there are n_in_spikes intervals to consider
# in_times and in_channels are the spike times and their corresponding input indices
n_in_times = 5
n_in_channels = 4
f_time = 42.0

in_times = np.sort(np.random.uniform(0, f_time, size=n_in_times))
in_channels = np.random.randint(0, n_in_channels, size=n_in_times)  # random input channels for the spikes

# we assume the n_in_times are sorted
# and we have 0 <= t_i < s for all t_i in in_times
in_coef = np.zeros((2, n_in_times, n_in_channels))  # shape (n_inputs, 2)
tmp_ind = np.arange(n_in_times)
in_coef[1, tmp_ind, in_channels[tmp_ind]] += 1.0
for n in range(1, n_in_times):
    dt = in_times[n] - in_times[n - 1]
    in_coef[0,n] += (in_coef[0, n-1] + in_coef[0, n-1] * dt) * np.exp(-dt)
    in_coef[1,n] += in_coef[1, n-1] * np.exp(-dt)

ends = np.diff(in_times, append=f_time)

# %%
def init_in_coef(f_times:np.ndarray, in_times:np.ndarray, in_channels:np.ndarray, n_in_channels:np.intp) -> np.ndarray:
    # now, consider many firing times, each having its own subintervals
    # period = 100.0
    # n_f_times = 3
    # f_times = np.sort(np.random.uniform(0, period, size=n_f_times))
    # n_in_times = 5
    # n_in_channels = 4
    # in_times = np.sort(np.random.uniform(0, f_times[-1], size=n_in_times))
    # in_channels = np.random.randint(0, n_in_channels, size=n_in_times)  # random input channels for the spikes

    # assume ti < f_times[-1] for every ti in_times
    f_times = np.sort(f_times) # not necessary??
    in_times = np.sort(in_times)

    in_coef = np.zeros((2, in_times.size, n_in_channels))  # shape (n_inputs, 2)
    
    # compute the insertion positions of the firing times in the input times array
    ipos = np.searchsorted(in_times, f_times, side='left')  # number of intervals for each firing time
    ipos = np.append(ipos, in_times.size)
    ipos = np.unique(ipos)

    print(f"f_times: {f_times}")
    print(f"in_times: {in_times}")
    print(f"in_channels: {in_channels}")

    n0 = 0
    for nmax in ipos:
        in_coef[1, n0, in_channels[n0]] = 1.0
        for n in range(n0+1, nmax):
            dt = in_times[n] - in_times[n - 1]
            in_coef[0,n] += (in_coef[0, n-1] + in_coef[1, n-1] * dt) * np.exp(-dt)
            in_coef[1,n] += in_coef[1, n-1] * np.exp(-dt)
            in_coef[1, n, in_channels[n]] += 1.0
        n0 = nmax


    # n_inter depends on the number of input spikes but also on the template itself 
    # we need to return:
    #  in_coef, an array with shape (2, n_inter, n_channels)
    #  zmax, an array with shape (n_inter)
    #  ends, an array with shape (n_inter)
    # all are computed from the template

    # 

    return in_coef

# %%
eps = 10.0
period = 100.0
n_f_times = 5
n_in_times = 10

f_times = np.sort(np.random.uniform(0, period, size=n_f_times))
in_times = np.sort(np.random.uniform(0, f_times[-1], size=n_in_times))
bf_times = f_times - eps
print(f"bf_times: {bf_times}")
print(f"f_times: {f_times}")
print(f"in_times: {in_times}")
# Out:
# bf_times: [-8.17821464 16.84273824 31.8841312  45.79219783 76.65783549]
# f_times: [ 1.82178536 26.84273824 41.8841312  55.79219783 86.65783549]
# in_times: [ 0.49178469  3.1180875   7.14583659 25.74915188 34.08348035 64.30034582
#  67.57301143 77.44500688 78.55799656 81.21936233]

# %%
i = 1 # ith interval
b_indices = np.searchsorted(in_times, bf_times, side='left') - 1
indices = np.searchsorted(in_times, f_times, side='left') - 1
print(f"the {i}th interval [{bf_times[i]}, {f_times[i]}) overlaps the states induced by all in_times between {in_times[b_indices[i]]} and {in_times[indices[i]]}")
# Out:
# the 1th interval [16.842738235978658, 26.842738235978658) overlaps the states induced by all in_times between 7.145836589856869 and 25.74915187873333

# %% [markdown]
# # Input Signals Via Piecewise Fading Linear Functions

# %%
# another alternative is to compute the coefficients one firing window at a time
from typing import Tuple
import numpy as np


def compute_in_states(
    f_time: np.float32,
    bf_time: np.float32,
    in_times: np.ndarray,
    in_channels: np.ndarray,
    n_in_channels: np.intp,
) -> Tuple[np.ndarray, np.ndarray]:
    """
    Compute the coefficients (c0nk and c1nk) defining the states of every input (indexed by k) for any time between 0 and f_time, on disjoint intervals (indexed by n).
    The intervals partition the time range [0, f_time] in n_intervals = in_times.size + 3 intervals from the following time markers:
    - 0.0, the start of the time range
    - bf_time, the time before firing (the beginning of the active region)
    - f_time, the firing time
    - in_times, the input spike times.
    The intervals are reconstructed from their start and length.
    The signal (c0nk + c1nk * dt) * exp(-dt) for 0 <= dt < length[n] then corresponds to 
    a) the kth input signal on the nth interval [start[n], start[n] + length[n]) if start[n] + length[n] < bf_time.
    b) the derivative of the kth input signal on the nth interval [start[n], start[n] + length[n]) if start[n] + length[n] < f_time and start[n] >= f_time.
    c) the kth input signal on the nth interval [start[n], start[n] + length[n]) if start[n] = f_time.

    Args:
        f_time (np.float32): _description_
        bf_time (np.float32): _description_
        in_times (np.ndarray): _description_
        in_channels (np.ndarray): _description_
        n_in_channels (np.intp): _description_

    Returns:
        np.ndarray: the coefficients defining the input signals by parts with shape (2, n_intervals, n_channels)
        np.ndarray: the times at which the intervals start with shape (n_intervals)
        np.ndarray: the lengths the intervals, with shape (n_intervals)
    """
    # Extract the in_times and in_channels that are valid, i.e., within the range [0, f_time)
    valid = (in_times >= 0.0) & (in_times < f_time)
    in_times = in_times[valid]
    in_channels = in_channels[valid]

    # Initialize the starts array
    starts = np.concatenate((in_times, np.array([0.0, f_time, bf_time])))

    # Initialize the coefficients array
    in_coef = np.zeros((2, starts.size, n_in_channels))
    in_coef[1, np.arange(in_times.size), in_channels] = 1.0

    # Sort the coefficients according to their starts
    sort_ids = np.argsort(starts)
    starts = starts[sort_ids]
    lengths = np.diff(starts, append=f_time)  # time differences = lengths of the intervals
    # ends = starts + lengths

    in_coef = in_coef[:, sort_ids, :]
    for n in range(starts.size - 1):
        in_coef[1, n + 1] += in_coef[1, n] * np.exp(-lengths[n])
        in_coef[0, n + 1] += (in_coef[0, n] + in_coef[1, n] * lengths[n]) * np.exp(-lengths[n])

    # The signal of interest on the active region is the (negative) derivative
    active = (starts >= bf_time) & (starts < f_time)
    in_coef[0, active] -= in_coef[1, active]  # (negative) derivative

    return in_coef, starts, lengths

# %%
f_time = 100.0
n_in_times = 50
n_in_channels = 5

in_times = np.random.uniform(0, f_time, size=n_in_times)
in_channels = np.random.randint(0, n_in_channels, size=n_in_times)

# %%
bf_time = f_time
in_coef, starts, durations = compute_in_states(f_time, bf_time, in_times, in_channels, n_in_channels)

# %%
fig, axes = plt.subplots(2, 1, figsize=(6, 3), sharex=True, height_ratios=(5, 1))

for n in range(in_coef.shape[1]):
    for k in range(n_in_channels):
        dt_vals = np.arange(0, durations[n], 1e-2)
        t_vals = dt_vals + starts[n]
        y_vals = (in_coef[0, n, k] + in_coef[1, n, k] * dt_vals) * np.exp(-dt_vals)
        axes[0].plot(t_vals, y_vals, c=f"C{k}", linewidth=1.5)
        

for n in range(in_times.size):
    axes[1].axvline(in_times[n], color=f'C{in_channels[n]}')

axes[1].set_xlabel('t')
axes[0].set_title('Per Channel Signals')
axes[1].set_ylabel('Spikes')
axes[1].set_yticks([])
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
axes[0].set_xlim(0, 100.0)
# axes[1].legend([f"ch. {k+1}" for k in range(n_in_channels)], bbox_to_anchor=(0.5, -1.55), loc='upper center', ncol=5)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(6, 3), sharex=True, height_ratios=(5, 1))

for n in range(in_coef.shape[1]):
    dt_vals = np.arange(0, durations[n], 1e-2)
    t_vals = dt_vals + starts[n]
    y_vals = (np.sum(in_coef[0, n]) + np.sum(in_coef[1, n]) * dt_vals) * np.exp(-dt_vals)
    axes[0].plot(t_vals, y_vals, c="C0", linewidth=1.5)
        

for n in range(in_times.size):
    axes[1].axvline(in_times[n], color='C0')

axes[1].set_xlabel('t')
axes[0].set_title('Potential')
axes[1].set_yticks([])
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
axes[0].set_xlim(0, 100.0)

plt.tight_layout()
plt.show()

# %%
bf_time = 0.0
in_coef, starts, durations = compute_in_states(f_time, bf_time, in_times, in_channels, n_in_channels)

# %%
fig, axes = plt.subplots(2, 1, figsize=(6, 3), sharex=True, height_ratios=(5, 1))

for n in range(in_coef.shape[1]):
    for k in range(n_in_channels):
        dt_vals = np.arange(0, durations[n], 1e-2)
        t_vals = dt_vals + starts[n]
        y_vals = -(in_coef[0, n, k] + in_coef[1, n, k] * dt_vals) * np.exp(-dt_vals)
        axes[0].plot(t_vals, y_vals, c=f"C{k}", linewidth=1.5)
        

for n in range(in_times.size):
    axes[1].axvline(in_times[n], color=f'C{in_channels[n]}')

axes[1].set_xlabel('t')
axes[0].set_title('Per Channel Signal Derivative')
axes[1].set_yticks([])
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
axes[0].set_xlim(0, 100.0)
# axes[0].legend([f"ch. {k+1}" for k in range(n_in_channels)], bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=5)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(6, 3), sharex=True, height_ratios=(5, 1))

for n in range(in_coef.shape[1]):
    dt_vals = np.arange(0, durations[n], 1e-2)
    t_vals = dt_vals + starts[n]
    y_vals = -(np.sum(in_coef[0, n]) + np.sum(in_coef[1, n]) * dt_vals) * np.exp(-dt_vals)
    axes[0].plot(t_vals, y_vals, c="C0", linewidth=1.5)
        

for n in range(in_times.size):
    axes[1].axvline(in_times[n], color='C0')

axes[1].set_xlabel('t')
axes[0].set_title('Potential Derivative')
# axes[1].set_ylabel('Spikes')
axes[1].set_yticks([])
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
axes[0].set_xlim(0, 100.0)

plt.tight_layout()
plt.show()

# %%
def mod(x, modulus, offset=0.0):
    """
    Compute the modulo operation with a given modulus and offset.
    """
    return x - modulus * np.floor((x - offset) / modulus)

# for n in n_f_times:
#     tmp_in_times = ((in_times % period) + period) % period

x = np.linspace(0, 5, 10)
y = mod(x, 5.0, offset=-1.0)
x, y
# Out:
# (array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#         2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ]),
#  array([ 0.        ,  0.55555556,  1.11111111,  1.66666667,  2.22222222,
#          2.77777778,  3.33333333,  3.88888889, -0.55555556,  0.        ]))

# %%
period = 100.0
eps = 1.0

n_f_times = 5
n_in_times = 50
n_in_channels = 6

f_times = np.sort(np.random.uniform(0, period, size=n_f_times))
in_times = np.random.uniform(0, period, size=n_in_times)
in_channels = np.random.randint(0, n_in_channels, size=n_in_times)  # random input channels for the spikes

# %%
# print(f"f_times: {f_times}")
# print(f"in_times: {in_times}")
# print(f"in_channels: {in_channels}")

fig, axes = plt.subplots(2, 1, figsize=(6, 3), sharex=True, height_ratios=(5, 1))

for n in range(n_f_times):
    f_time = (f_times[n] - f_times[n - 1]) % period
    bf_time = f_time - eps
    in_coef, starts, durations = compute_in_states(
        f_time,
        f_time,
        (in_times - f_times[n - 1]) % period,
        in_channels,
        n_in_channels,
    )

    for m in range(in_coef.shape[1]):
        dt_vals = np.arange(0, durations[m], 1e-2)
        t_vals = dt_vals + starts[m] + f_times[n - 1]
        y_vals = (np.sum(in_coef[0, m]) + np.sum(in_coef[1, m]) * dt_vals) * np.exp(-dt_vals)
        axes[0].plot(t_vals, y_vals, c="C0", linewidth=1.5)

    axes[0].axvline(f_times[n], color='black', linestyle='--', linewidth=1.0, alpha=0.7)
    axes[1].axvline(f_times[n], color='black', linestyle='--', linewidth=1.0, alpha=0.7)
        
for m in range(in_times.size):
    axes[1].axvline((in_times[m] - f_times[0])%period + f_times[0], color='C0')

axes[1].set_xlabel('t')
axes[0].set_title('Potential')
axes[1].set_yticks([])
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
axes[0].set_xlim(f_times[0], f_times[0] + period)

plt.tight_layout()
plt.show()
